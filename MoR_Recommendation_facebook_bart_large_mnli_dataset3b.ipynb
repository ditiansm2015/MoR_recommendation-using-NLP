# %% [markdown]
# <a href="https://colab.research.google.com/github/ditiansm2015/MoR_recommendation-using-NLP/blob/main/MoR_Recommendation_facebook_bart_large_mnli_dataset3b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Importing required libraries

import pandas as pd
import numpy as  np
import random as rd
import matplotlib.pyplot as plt

# %%
## To import dataset from local drive

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87656923-2102-4066-a244-d4ed067f3b2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87656923-2102-4066-a244-d4ed067f3b2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving new_dataset3b.csv to new_dataset3b.csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.StringIO(uploaded['new_dataset3b.csv'].decode('cp1252')))

df.shape
# Out:
# (165, 2)

# %%
messages = df.copy()
messages.head
# Out:
# <bound method NDFrame.head of          WOM_ROLE                               WOM Description
# 0    PT/BDO-CD-AP                          Digital Coordination
# 1    PT/BDO-OF-AP                             Digital Offerings
# 2    PT/BDO-ED-AP                            Digital Enablement
# 3    PT-MT/SCN-AM                       TT Business development
# 4    PT-BI/LOP-AP                    Distribution Management BI
# ..            ...                                           ...
# 160    PT/PUB-EX4              Purchasing Buyout Execution - MT
# 161    PT/PUB-EX5              Purchasing Buyout Execution - RT
# 162     PT/PUB-SQ  Purchasing Buyout Execution Shipment Quality
# 163     PT/PUB-BT                Purchasing Buyout Execution-BT
# 164     PT/HRL-Hz                      Human Resources Hangzhou
#
# [165 rows x 2 columns]>

# %%
messages = messages.dropna()

# %%
messages.reset_index(inplace = True)

# %%
corpus= []
for i in range(0, len(messages)):
  review = messages['WOM Description'][i]
  review = ''.join(review)
  corpus.append(review)

corpus
# Out:
# ['Digital Coordination',
#  'Digital Offerings',
#  'Digital Enablement',
#  'TT Business development',
#  'Distribution Management BI',
#  'Product Training',
#  'Sales Operations Greater China',
#  'Sales Operations - LOG',
#  'Sales Operations - SBO',
#  'Sales Operations - Controlling',
#  'Sales Greater China',
#  'Retail Marketing – China',
#  'Channel Sales Multiple',
#  'TT District Management E',
#  'TT District Management F',
#  'TT District Management G',
#  'TT District Management in Shanghai& Jiangsu',
#  "TT District Management in He'nan&Hubei",
#  'Digital Business Development',
#  'Key users management',
#  'Key users management',
#  'Key users management',
#  'Key users management',
#  'Key users management',
#  'Sales & Marketing',
#  'Plant Controlling',
#  'Product Purchasing',
#  'Product Purchasing (Drill/Hammer/ Angle Grinder)',
#  'Product Purchasing (Drill/Hammer)',
#  '"Product Purchasing (Angle Grinder)"',
#  '"Product Purchasing (Circular & Jig Saw)"',
#  'After Sales Service',
#  'Bosch after sales service center',
#  'Supply Chain Management Emerging Markets',
#  'Distribution Management BE',
#  'Vice President Engineering',
#  'ENG Tech & Drive System For BE',
#  'DC/DC-EC Solution Team',
#  'AC/AC-EC Solution Team',
#  'Eng Technology & Drive System',
#  'BE Drive System Team',
#  'project management for NE',
#  'Execution team- Light drilling and Chiseling',
#  'Value stream team',
#  'Rough Drilling VS',
#  'Manufacturing Operations',
#  'Manufacturing Process Optimization',
#  'PT BE Agile Business Team_Execution Team for Cutting',
#  'Valume Stream Team',
#  'Manufacturing Operations',
#  'Manufacturing Process Operations',
#  'PT BE Agile Business Team_Execution Team for Grinding',
#  'Valume Stream Team',
#  'Angle Grinder VS',
#  'Manufacturing Operations',
#  'Manufacturing Process Optimization',
#  'PT BE Agile Business Team_Execution Team for Finishing',
#  'Value Stream Team',
#  'PT BE Agile Business Team_Execution Team for Demolition',
#  'Value stream team',
#  'Demolition VS',
#  'Manufacturing Operations',
#  'ENG Product Support in Hangzhou',
#  'Line Support & ALR',
#  'Product Test & Lab',
#  'Simulation (Advance ENG)',
#  'ENG Tech & Shared Service @Hz',
#  'Documentation & Engineering Services',
#  'Testing Center',
#  'Accreditation Testing',
#  'Cerfication ,regulation,process and DFE',
#  'BE excellence of engineering expertise',
#  'BE Manufacturing Technologies',
#  'Manufacturing Process',
#  'BE MAD Design & Construction',
#  'Electrical design for MAE',
#  'Mechanical design & MAE building',
#  'Quality Management & Methods',
#  'PT BE Product Quality Management',
#  'AC Value Stream Quality',
#  'Quality System, Methods, Q-reporting',
#  'Value Stream Quality and New Product Quality',
#  'Incoming & in house Inspection management',
#  'Value Stream Quality',
#  'HzP/QMM-MXD',
#  'Value stream quality',
#  'Manufacturing',
#  'Plant Manager',
#  'Manufacturing Circular Saw Blades',
#  'Manufacturing perations',
#  'Manufacturing Engineering',
#  'Manufacturing Hole Saw',
#  'Manufacturing Production',
#  'Accessories Packaging',
#  'Manufacturing Masonary Drill Bits',
#  'Manufacturing perations',
#  'Manufacturing Engineering',
#  'Manufacturing Carbide Tips',
#  'Manufacturing Production',
#  'Manufacturing Engineering',
#  'Manufacturing Engineering',
#  'Manufacturing Operations',
#  'HzP/MSE9-VSE',
#  'Manufacturing',
#  'Manufacturing Operations',
#  'Manufacturing Process Engineering Motor',
#  'Technical Functions',
#  'Technical Functions',
#  'Equipment Maintenance',
#  'Preventive Maintenance',
#  'Corrective Maintenance',
#  'Corrective Maintenance',
#  'Manufacturing Process Engineering Assembly',
#  'Manufacturing Process Engineering Motor',
#  'Equipment Design & Construction',
#  'Bosch Production System',
#  'Physical Plant Logistics',
#  'Supply Management AC',
#  'Supply Management_Customer Order Fulfillment',
#  'Process, Systems, Controlling',
#  'Supply Management',
#  'Supply Management',
#  'Supply Management',
#  'Supply Management',
#  'Manufacturing',
#  'Manufacturing',
#  'General Manager',
#  'Health, Safety & Environment',
#  'Protection and Security Officer',
#  'Vice President Finance and Administration',
#  'Legal Entity Controlling & Internal Control',
#  'Facility Management',
#  'Facility Management Building and utility',
#  'Facility Management Security,Cleaning',
#  'PT-AC/SCN',
#  'Brand Management Acc.',
#  'PT-AC/SCN-AM',
#  'Marketing Flexible Abrasives Asia-Pacific',
#  'Purchasing',
#  'Purchasing Quality',
#  'Engineering, Design and Projects Packaging',
#  'regional marketing for PA1',
#  'Engineering Prototyping Carbide',
#  'regional marketing for PA5',
#  'supply chain planning for EU',
#  'Logistic AP',
#  'Distribution Management Asia Pacific',
#  'Quality Management & Methods Region Asia Pacific',
#  'Project Quality Engineering Buyout CN and AP',
#  'project mgmt, test lab, prototype mgmt',
#  'Divisional Logistics Asia Pacific',
#  'Purchasing Quality China',
#  'Purchasing Quality China',
#  'Commodity Purchasing China',
#  'Commodity Purchasing China',
#  'Purchasing Buyout Execution',
#  'Purchasing Buyout Execution Expertise Team',
#  'Purchasing Buyout Execution - BI',
#  'Purchasing Buyout Execution - BE',
#  'Purchasing Buyout Execution - HG',
#  'Purchasing Buyout Execution - MT',
#  'Purchasing Buyout Execution - RT',
#  'Purchasing Buyout Execution Shipment Quality',
#  'Purchasing Buyout Execution-BT',
#  'Human Resources Hangzhou']

# %%
pip install txtai
# Out:
# Collecting txtai
#   Downloading https://files.pythonhosted.org/packages/4a/96/17a6e327e566c937e312cc977c77a8d71f0a5d4766c934f0a488bbb7121a/txtai-3.1.0-py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 5.2MB/s
# Collecting nltk>=3.5
#   Downloading https://files.pythonhosted.org/packages/5e/37/9532ddd4b1bbb619333d5708aaad9bf1742f051a664c3c6fa6632a105fd8/nltk-3.6.2-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 12.5MB/s
# Collecting fastapi>=0.61.1
#   Downloading https://files.pythonhosted.org/packages/4e/b9/a91a699f5c201413b3f61405dbccc29ebe5ad25945230e9cec98fdb2434c/fastapi-0.65.1-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.2MB/s
# Collecting scikit-learn>=0.23.1
#   Downloading https://files.pythonhosted.org/packages/a8/eb/a48f25c967526b66d5f1fa7a984594f0bf0a5afafa94a8c4dbc317744620/scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 1.5MB/s
# Collecting faiss-cpu>=1.7.0; os_name != "nt"
#   Downloading https://files.pythonhosted.org/packages/48/0c/efd43c4feac172867409f38f07949c36602355ec7196749d10f905d09228/faiss_cpu-1.7.0-cp37-cp37m-manylinux2014_x86_64.whl (8.1MB)
#      |████████████████████████████████| 8.2MB 49.2MB/s
# Collecting PyYAML>=5.3
#   Downloading https://files.pythonhosted.org/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636kB)
#      |████████████████████████████████| 645kB 38.0MB/s
# Collecting pillow>=7.2.0
#   Downloading https://files.pythonhosted.org/packages/33/34/542152297dcc6c47a9dcb0685eac6d652d878ed3cea83bf2b23cb988e857/Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 39.7MB/s
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.7/dist-packages (from txtai) (1.19.5)
# Collecting tika>=1.24
#   Downloading https://files.pythonhosted.org/packages/96/07/244fbb9c74c0de8a3745cc9f3f496077a29f6418c7cbd90d68fd799574cb/tika-1.24.tar.gz
# Collecting fasttext>=0.9.2
#   Downloading https://files.pythonhosted.org/packages/f8/85/e2b368ab6d3528827b147fdb814f8189acc981a4bc2f99ab894650e05c40/fasttext-0.9.2.tar.gz (68kB)
#      |████████████████████████████████| 71kB 7.9MB/s
# Collecting annoy>=1.16.3
#   Downloading https://files.pythonhosted.org/packages/a1/5b/1c22129f608b3f438713b91cd880dc681d747a860afe3e8e0af86e921942/annoy-1.17.0.tar.gz (646kB)
#      |████████████████████████████████| 655kB 49.5MB/s
# Collecting aiohttp>=3.7.4
#   Downloading https://files.pythonhosted.org/packages/88/c0/5890b4c8b04a79b7360e8fe4490feb0bb3ab179743f199f0e6220cebd568/aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 70.0MB/s
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from txtai) (1.8.1+cu101)
# Collecting requests>=2.24.0
#   Downloading https://files.pythonhosted.org/packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 7.9MB/s
# Collecting sentencepiece>=0.1.91
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 53.9MB/s
# Collecting regex>=2020.5.14
#   Downloading https://files.pythonhosted.org/packages/c4/28/5f08d8841013ccf72cd95dfff2500fe7fb39467af12c5e7b802d8381d811/regex-2021.4.4-cp37-cp37m-manylinux2014_x86_64.whl (720kB)
#      |████████████████████████████████| 727kB 48.1MB/s
# Collecting hnswlib>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/03/8c/3e0e608278b740f2a78ba76ba406dbecc8b7d3ce8cfb858580f13ea04930/hnswlib-0.5.1.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pymagnitude-lite>=0.1.43
#   Downloading https://files.pythonhosted.org/packages/e0/8c/94b5e7c7ef2f40091aa9ffdaeabb3f89b48a49610ac9415ca16844d9b1b4/pymagnitude_lite-0.1.143-py3-none-any.whl
# Collecting transformers>=4.4.2
#   Downloading https://files.pythonhosted.org/packages/d5/43/cfe4ee779bbd6a678ac6a97c5a5cdeb03c35f9eaebbb9720b036680f9a2d/transformers-4.6.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.3MB 51.3MB/s
# Collecting apache-libcloud>=3.3.1
#   Downloading https://files.pythonhosted.org/packages/fc/2d/af7696ba6f83e30fe2a8e34c79b96639c6d9e1398c2dee6d461991eb2fd2/apache_libcloud-3.3.1-py2.py3-none-any.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 52.4MB/s
# Collecting sentence-transformers>=1.0.3
#   Downloading https://files.pythonhosted.org/packages/cc/75/df441011cd1726822b70fbff50042adb4860e9327b99b346154ead704c44/sentence-transformers-1.2.0.tar.gz (81kB)
#      |████████████████████████████████| 81kB 8.1MB/s
# Collecting tqdm>=4.46.0
#   Downloading https://files.pythonhosted.org/packages/42/d7/f357d98e9b50346bcb6095fe3ad205d8db3174eb5edb03edfe7c4099576d/tqdm-4.61.0-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 9.2MB/s
# Requirement already satisfied: soundfile>=0.10.3.post1 in /usr/local/lib/python3.7/dist-packages (from txtai) (0.10.3.post1)
# Collecting uvicorn>=0.12.1
#   Downloading https://files.pythonhosted.org/packages/c8/de/953f0289508b1b92debdf0a6822d9b88ffb0c6ad471d709cf639a2c8a176/uvicorn-0.13.4-py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.5->txtai) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.5->txtai) (1.0.1)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading https://files.pythonhosted.org/packages/9f/f2/2d5425efe57f6c4e06cbe5e587c1fd16929dcf0eb90bd4d3d1e1c97d1151/pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 27.9MB/s
# Collecting starlette==0.14.2
#   Downloading https://files.pythonhosted.org/packages/15/34/db1890f442a1cd3a2c761f4109a0eb4e63503218d70a8c8e97faa09a5500/starlette-0.14.2-py3-none-any.whl (60kB)
#      |████████████████████████████████| 61kB 7.1MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.1->txtai) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tika>=1.24->txtai) (56.1.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext>=0.9.2->txtai) (2.6.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.7.4->txtai) (21.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.7.4->txtai) (3.7.4.3)
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/f1/62/046834c5fc998c88ab2ef722f5d42122230a632212c8afa76418324f53ff/yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294kB)
#      |████████████████████████████████| 296kB 68.1MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/7c/a6/4123b8165acbe773d1a8dc8e3f0d1edea16d29f7de018eda769abb56bd30/multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142kB)
#      |████████████████████████████████| 143kB 64.1MB/s
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.7.4->txtai) (3.0.4)
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->txtai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->txtai) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->txtai) (2.10)
# Collecting lz4>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/e3/52/151c815a486290608e4dc6699a0cfd74141dc5191f8fe928e7d1b28b569e/lz4-3.1.3-cp37-cp37m-manylinux2010_x86_64.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 52.9MB/s
# Collecting fasteners>=0.14.1
#   Downloading https://files.pythonhosted.org/packages/78/20/c862d765287e9e8b29f826749ebae8775bdca50b2cb2ca079346d5fbfd76/fasteners-0.16-py2.py3-none-any.whl
# Collecting xxhash>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 70.8MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers>=4.4.2->txtai) (4.0.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 56.2MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 50.2MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=4.4.2->txtai) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.4.2->txtai) (3.0.12)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=1.0.3->txtai) (0.9.1+cu101)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.3.post1->txtai) (1.14.5)
# Collecting h11>=0.8
#   Downloading https://files.pythonhosted.org/packages/60/0f/7a0eeea938eaf61074f29fed9717f2010e8d0e0905d36b38d3275a1e4622/h11-0.12.0-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 6.9MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fasteners>=0.14.1->pymagnitude-lite>=0.1.43->txtai) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers>=4.4.2->txtai) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=4.4.2->txtai) (2.4.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.3.post1->txtai) (2.20)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (PEP 517) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.5.1-cp37-cp37m-linux_x86_64.whl size=1292702 sha256=e4a0d4dcfbcddc96e17252612e860d0f2c4c1a24969f3c23b7c2df00940fde52
#   Stored in directory: /root/.cache/pip/wheels/46/7b/98/44c3a8a284506a54993f0b321e4a32a0c9e69215bbb72feff5
# Successfully built hnswlib
# Building wheels for collected packages: tika, fasttext, annoy, sentence-transformers
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-cp37-none-any.whl size=32885 sha256=faeb81a155cd4b67e9a96051d7abc030cc678a6525f8642688665071ab0612d1
#   Stored in directory: /root/.cache/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3092719 sha256=07c493f640e74141e96249520024461ff60bef0e344b047ff6be8e72599e9959
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.0-cp37-cp37m-linux_x86_64.whl size=387004 sha256=08557c3825c23c34a49e6ad5c8a4f4f948e9b3e4c7e1f5a5ea31a6f3e13ee35f
#   Stored in directory: /root/.cache/pip/wheels/3a/c5/59/cce7e67b52c8e987389e53f917b6bb2a9d904a03246fadcb1e
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.2.0-cp37-none-any.whl size=123339 sha256=6e1dbbdcaa552e67dba8063b3366415bea18c052f0b39dbec8559fa3d9b72659
#   Stored in directory: /root/.cache/pip/wheels/0f/06/f7/faaa96fdda87462b4fd5c47b343340e9d5531ef70d0eef8242
# Successfully built tika fasttext annoy sentence-transformers
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.25.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: tqdm, regex, nltk, pydantic, starlette, fastapi, threadpoolctl, scikit-learn, faiss-cpu, PyYAML, pillow, requests, tika, fasttext, annoy, multidict, yarl, async-timeout, aiohttp, sentencepiece, hnswlib, lz4, fasteners, xxhash, pymagnitude-lite, sacremoses, tokenizers, huggingface-hub, transformers, apache-libcloud, sentence-transformers, h11, uvicorn, txtai
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed PyYAML-5.4.1 aiohttp-3.7.4.post0 annoy-1.17.0 apache-libcloud-3.3.1 async-timeout-3.0.1 faiss-cpu-1.7.0 fastapi-0.65.1 fasteners-0.16 fasttext-0.9.2 h11-0.12.0 hnswlib-0.5.1 huggingface-hub-0.0.8 lz4-3.1.3 multidict-5.1.0 nltk-3.6.2 pillow-8.2.0 pydantic-1.8.2 pymagnitude-lite-0.1.143 regex-2021.4.4 requests-2.25.1 sacremoses-0.0.45 scikit-learn-0.24.2 sentence-transformers-1.2.0 sentencepiece-0.1.95 starlette-0.14.2 threadpoolctl-2.1.0 tika-1.24 tokenizers-0.10.3 tqdm-4.61.0 transformers-4.6.1 txtai-3.1.0 uvicorn-0.13.4 xxhash-2.0.2 yarl-1.6.3

# %%
from txtai.pipeline import Labels

# Create labels model
labels = Labels()
# Out:
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]

# %%
from google.colab import files

# List of labels
tags = ["Digital Office", "Executive", "Sales and Distribution", "Manufacturing", "Master Data", "Finance", "Controlling", "Logistics", "Quality Management","Non Categorized","Purchasing", "Facitlity management","Health Safety","Security", "Service","Plant Maintenance","Project System","Human Resource","Marketing","Operations","After Sales","Engineering","Value Stream","Technical Function"]

print("%-105s %s" % ("Text", "Label"))
print("-" * 112)

with open('example3.csv', 'w') as f:
  for text in corpus:
         ## print("%-105s %s" % (text, tags[labels(text, tags)[0][0]]))
         ku = tags[labels(text, tags)[0][0]]
         
         (f.write(ku + "\n"))

files.download('example3.csv')
# Out:
# Text                                                                                                      Label
# ----------------------------------------------------------------------------------------------------------------
